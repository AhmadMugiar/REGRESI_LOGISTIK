# %% [markdown]
# # Soal 1

# %% [markdown]
# Siti adalah seorang penjual tanaman hias di kota Yogyakarta. Ia menjual berbagai jenis tanaman seperti monstera, kaktus, anggrek, lidah mertua, dan bonsai. Berdasarkan kasus tersebut, lakukan tulis tangan langkah-langkah berikut menggunakan struktur data list dalam bahasa Python:
#
# a. Buatkan sebuah list yang berisi jenis tanaman yang dijual oleh Siti
#
# b. Siti berhasil menjual tanaman kaktus, maka hapus data tersebut dari list
#
# c. Siti mendapatkan stok baru yaitu lavender
#
#
# tampilkan output masing masing variabel-nya

# %% [markdown]
# # Soal 2

# %% [markdown]
# a. Suatu Brand sepatu mempunyai data stock ukuran untuk sepatu best seller mereka, kemudian brand tersebut memakai struktur data untuk kebutuhan manajemen agar terstukur. Tuliskan output apa yang sesuai!

# %%
ShoesSizeInStock = (39,38,41.5,40,42,44)
Stock = ShoesSizeInStock
Stock

# %%
if 41.5 in ShoesSizeInStock:
  print("Available In Stock")
else:
  print("not restocked yet")

# %%
if 43 in ShoesSizeInStock:
  print("Available In Stock")
else:
  print("not restocked yet")

# %%
maintence = list(Stock)
maintence[2] = 43
Stock = tuple(maintence)
Stock

# %% [markdown]
# b. Diketahui daftar menu bestseller dari Logic coffee sebagai berikut, tuliskan outputnya!

# %%
bestsellerLogicCoffee = {"V60", "Americano", 360, "Drip", "Cookies&Cream", 0.5, False, "Kapal Api", "Mocca", "Brew"}
datalogic = bestsellerLogicCoffee
datalogic

# %% [markdown]
# Lalu owner ingin mengecek apakah menu ini terdapat di menu bestseller, tuliskan outputnya!

# %%
print(0 in datalogic)

# %% [markdown]
# c. Diketahui lagi daftar bestseller dari coffeeshop lain yaitu Please Coffee sebagai berikut, tuliskan outputnya!

# %%
bestsellerpleasecofee = {"V60", "Drip", 365, "Cookies&Cream", True, "Mocca", "Brew", 0.5, "Americano", "Kapal Api"}
dataplease = bestsellerpleasecofee
dataplease

# %% [markdown]
# Lalu owner logic ingin membandingkan usahanya dengan Please Coffee, maka dilakukan analisis seperti berikut, tuliskan outputnya!

# %%
analisis = datalogic.symmetric_difference(dataplease)
analisis

# %%
korelasi = datalogic & dataplease
korelasi

# %% [markdown]
# # Soal 3

# %%
id_transaksi = {
    "TR128" : "Berhasil",
    "TR129" : "Gagal",
    "TR130" : "Refund",
    "TR131" : "Pending",
    "TR132" : "Berhasil",
}
id_transaksi
# Out:
# {'TR128': 'Berhasil',
#  'TR129': 'Gagal',
#  'TR130': 'Refund',
#  'TR131': 'Pending',
#  'TR132': 'Berhasil'}

# %% [markdown]
# a. Tambahkan transaksi dengan status "berhasil"
#
# b. Hapus transaksi yang memiliki status "gagal"
#
# c. id_transaksi,update({"TR133" : "Berhasil"}) Berikan outputnya

# %% [markdown]
# **error**

# %% [markdown]
# # Soal 4

# %%
class Stack:
  def __init__(self):
    self.items = []

  def is_empty(self):
    return len(self.items) == 0

  def push(self, item):
    self.items.append(item)

  def pop(self):
    if not self.is_empty():
      return self.items.pop()

  def peek(self):
    if not self.is_empty():
      return self.items[-1]

# %% [markdown]
#  Langkah awal buat variabel **Stacklist** dan masukan class utama pada stack di atas
#
# a. Tambahkan ke stack kosong Barang A, Barang B, Barang C, Barang D dan tampilkan outputnya
#
# b. Gunakan fungsi pada Stack untuk menghapus, dan berikan output Barang mana yang di hapus

# %% [markdown]
# c. Perhatikan dan gunakan logika alogirtmanya, Tuliskan Outputnya dari code di bawah

# %%
Stacklist2 = Stacklist
Stacklist2.push("Barang 1")
Stacklist2.push("Barang 2")
Stacklist2.push("Barang 3")

# %%
print(Stacklist2.items)
# Out:
# ['Barang A', 'Barang B', 'Barang C', 'Barang 1', 'Barang 2', 'Barang 3']

# %% [markdown]
# # Soal 5

# %%
class Queue:
  def __init__(self):
    self.items = []

  def is_empty(self):
    return len(self.items) == 0

  def enqueue(self, item):
    self.items.append(item)

  def dequeue(self):
    if self.is_empty():
      return None
    return self.items.pop(0)

  def peek(self):
    if self.is_empty():
      return None
    return self.items[0]

# %% [markdown]
# a. Adele dan Habibi mendengarkan lagu bersama di Spotify dengan Playlist yang diatur oleh Habibi, lalu habibi meng-entry lagu-lagu untuk mereka dengar, berikut lagu-lagu yang Habibi akan masukkan:
#
#
# *   Backburner - NIKI
# *   November Rain - Guns N' Roses
# *   Nobody Gets Me - SZA
#
# Buatkan variabel dan kode untuk menambah lagu pada playlist yang sesuai dengan apa yang habibi ingin masukkan dengan class dan fungsi yang sudah dibuat, lalu buat kode untuk menampilkan semua data lagu yang sudah di entry oleh habibi!

# %% [markdown]
# b. kemudian habibi dan adele sudah mendengarkan lagu bersama. Sistem pada playlist itu seperti berikut, tuliskan outputnya!
